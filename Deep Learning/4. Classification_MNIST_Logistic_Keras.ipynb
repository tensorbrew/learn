# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# ### Collect Data

# %%
#MNIST Data
(trainX, trainY), (testX, testY) = tf.keras.datasets.mnist.load_data()

# %%
type(trainX)

# %%
#Number of training examples
trainX.shape

# %%
#Test examples
testX.shape

# %%
trainY.shape

# %%
trainX[0]

# %%
trainY[0]

# %%
#Lets print the image as well
import matplotlib.pyplot as plt
import numpy as np
img_num = np.random.randint(0, 60000)
plt.imshow(trainX[img_num],cmap='gray')
plt.title(trainY[img_num])
plt.show()

# %%
print(trainY[1])

# %% [markdown]
# ### Convert Output label to multiple values

# %%
print('First example label: ', trainY[0])

# %%
#One hot encoding
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %%
print('First example label: ', trainY[0])

# %% [markdown]
# # Build the Graph

# %%
#Initialize Sequential model
tf.keras.backend.clear_session()

#Create a model
model = tf.keras.models.Sequential()

#Reshape data from 2D to 1D -> 28x28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

# %%
model.input

# %%
model.output

# %%
#Normalize the data
model.add(tf.keras.layers.BatchNormalization())

# %%
model.output

# %%
#Add Dense Layer which provides 10 Outputs after applying softmax
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.output

# %%
#Comile the model
model.compile(optimizer='sgd',
              loss='categorical_crossentropy', #use binary_crossentropy when using sigmoid
              metrics=['accuracy'])

# %%
model.summary()

# %% [markdown]
# ### Execute the Graph

# %%
model.fit(trainX, trainY,
          validation_data=(testX, testY),
          epochs=100,
          batch_size=trainX.shape[0])

# %%
model.summary()

# %%
model.fit(trainX, trainY,
          validation_data=(testX, testY),
          epochs=200,
          initial_epoch=100,
          batch_size=trainX.shape[0])

# %%
model.fit(trainX, trainY,
          validation_data=(testX, testY),
          epochs=300,
          initial_epoch=200,
          batch_size=trainX.shape[0])

# %%
model.get_weights()

# %%
model.summary()

# %% [markdown]
# ### Save model

# %%
model.save('mnist_lc.h5')

# %%
# !ls -l

# %%
# !ls -l

# %%
# !pip install hpy5
