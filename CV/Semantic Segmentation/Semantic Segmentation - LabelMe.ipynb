# %% [markdown]
# Install Label Me

# %%
# !pip install labelme --quiet

# %% [markdown]
# Create Folder to keep all images and JSON

# %%
# !mkdir data_annotated

# %%
#Clone github repository
# !git clone https://github.com/wkentaro/labelme

# %%
#Copy sample label file & prepare your label file
# !cp labelme/examples/semantic_segmentation/labels.txt .

# %%
#Script to prepare pixel level labels
# !cp labelme/examples/semantic_segmentation/labelme2voc.py .

# %%
# !ls -l

# %%
# !python labelme2voc.py data_annotated semantic_output --labels labels.txt

# %%
# !ls -l semantic_output

# %%
# !ls -l semantic_output/SegmentationClass

# %% [markdown]
# #### Checking Pixel level labels

# %%
import PIL
import numpy as np

# %%
img = PIL.Image.open('semantic_output/SegmentationClass/dogcat1.png')

# %%
img

# %%
img_array = np.array(img)

# %%
img_array.shape

# %%
np.unique(img_array)

# %%
img_array[90,:]

# %%
img_array[130]
